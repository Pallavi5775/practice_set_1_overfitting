# %%
import pandas as pd
import numpy as np

df = pd.read_csv('my_dataset.csv')
df
# Out:
#       Age  Income  Credit_Score  Loan_Amount  Loan_Term  Interest_Rate  \
# 0      56   29930           839       401314         48       9.125587
# 1      69   23285           811        32020         48       4.191150
# 2      46  143637           510       455488         72       4.277766
# 3      32   55863           552       127043         48       9.300053
# 4      60   36704           337       449555         60       1.612464
# ...   ...     ...           ...          ...        ...            ...
# 9995   55   23333           702        36455         36       2.802468
# 9996   51   60002           630       231420         72       2.918479
# 9997   57  144477           756       333704         72       8.274231
# 9998   64   83620           782       358908         12       7.475442
# 9999   32  107688           797       152993         36       5.805488
#
#       Monthly_Installment  Debt_to_Income_Ratio  Employment_Length  \
# ...
